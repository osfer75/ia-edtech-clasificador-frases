# %%
def saludar():
    print("Hola, bienvenido a Python!")

# ejecutar la función
saludar()
# Out:
# Hola, bienvenido a Python!

# %%
def saludar_persona(nombre):
    print("Hola " + nombre + "!")

saludar_persona("Oscar")
saludar_persona("Ana")
# Out:
# Hola Oscar!
# Hola Ana!

# %%
def sumar(a, b):
    return a + b

resultado = sumar(5, 7)
print("La suma es:", resultado)
# Out:
# La suma es: 12

# %%
def cuadrado(numero):
    return numero * numero

resultado = cuadrado(9)

print("el cuadrado de 9 es:" , resultado)
# Out:
# el cuadrado de 9 es: 81

# %%
def presentacion(nombre, edad):
    print("Hola " + nombre + ", tienes " + edad + " años")

presentacion("ana", "25")
# Out:
# Hola ana, tienes 25 años

# %%
def promedio(lista):
    return sum(lista) / len(lista)
prom = promedio([2,3,4,5,6])

print("el promedio de los numeros es,",  prom)
# Out:
# el promedio de los numeros es, 4.0

# %%
def es_par(numero) :
    return numero % 2 == 0

print(es_par(4)) # True
print(es_par(7)) # False
# Out:
# True
# False

# %%
assert cuadrado(6) == 36
assert presentacion("Luis", 30) == "Hola Luis, tienes 30 años"
assert es_par(10) is True
assert promedio([2,4]) == 3.0
print("Todos los tests pasaron ✅")
# Out:
# ---------------------------------
# TypeErrorTraceback (most recent call last)
# Cell In[27], line 2
#       1 assert cuadrado(6) == 36
# ----> 2 assert presentacion("Luis", 30) == "Hola Luis, tienes 30 años"
#       3 assert es_par(10) is True
#       4 assert promedio([2,4]) == 3.0
#
# Cell In[16], line 2, in presentacion(nombre, edad)
#       1 def presentacion(nombre, edad):
# ----> 2     print("Hola " + nombre + ", tienes " + edad + " años")
#
# TypeError: can only concatenate str (not "int") to str

# %%
# funciones.py
def cuadrado(numero):
    return numero * numero

def presentacion(nombre, edad):
    return f"Hola {nombre}, tienes {edad} años"

def promedio_safe(lista):
    if not lista:
        return None
    return sum(lista) / len(lista)

def es_par(numero):
    return numero % 2 == 0
